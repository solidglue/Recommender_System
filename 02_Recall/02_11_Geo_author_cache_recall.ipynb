# %% [markdown]
# ![~~image.png~~](attachment:image.png)

# %% [markdown]
# ![~~image.png~~](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 心得

#1、作者召回可以用到短视频召回，例如关注作者、相似作者;
#2、缓存召回，目前线上没有这里召回，伪曝光节目会被丢弃，
# 其实这里边很可能存在用户感兴趣内容。
