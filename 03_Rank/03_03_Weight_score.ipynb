# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 心得

#1、对于电商要下单才算转化，需要用乘法融合分数；
#2、对于视频/笔记类，收藏、点赞、转发都可以算转化，可以用加法融合。
#3、也可以MMOE学习，但是无法人工干预各指标权重（有时候考核需要）。
