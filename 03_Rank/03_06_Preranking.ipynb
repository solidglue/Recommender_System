# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 心得

#1、召回的双塔和排序的双塔优化目标不一样，召回一般是单目标，粗排往往多目标。
#召回双塔-两个向量的余弦相似度作为兴趣的预估值；
#粗排双塔-点击率、转化率等指标。

#2、双塔召回与双塔粗排的样本不一样
#召回：对于负样本的选取，大部分实验采用随机采样物料库当做负样本。
#这样能保证在召回的模型中见到不同的物料。
#粗排：在粗排环节，一般来说，样本分布和精排是一致的。所以这里曝光下载当作正样本，
#曝光未下载当做负样本。

#3、评估
#召回使用的评估指标是hit rate等指标
#粗排一般使用排序的评估指标auc、uauc等

#https://www.zhihu.com/question/481531973/answer/3082660411?utm_id=0
