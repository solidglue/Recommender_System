# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 心得

# 在WDL之后，有越来越多的工作集中于分别改进Wide部分和Deep部分。
#2017年，谷歌针对WDL的Wide部分进行改进，提出了Deep&Cross模型（简称DCN）。
#其主要思路是使用Cross网络替代原来的Wide网络，以此提升模型的交叉能力。

#交叉网络的的计算公式如下，由公式可以看到，每一层的值都是上一层和embedding层输出x0之间做交叉。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 交叉网络的的计算公式如下，由公式可以看到，每一层的值都是上一层和embedding层输出x0之间做交叉。
# ![image-2.png](attachment:image-2.png)
#
# 交叉网络每一层计算的可视化图示如下：
# ![image.png](attachment:image.png)
