# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 心得

#1、 AB粒度更细，而不仅仅是用户维度ab。还有作者维度ab：

# 方案1：给一个用户同时推老笔记，新笔记a，新笔记b（2个新笔记作者策略ab）；
# 缺点，新老笔记抢流量，新比较之间也抢流量。

# 方案2：给用户推老笔记，分群推新笔记，一个用户只会看到老笔记+新笔记（a或者b），
# 缺点，新笔记直接不会抢流量（作者侧实验更可信），但是新老笔记会抢流量。

# 方案3：新老笔记都分流用户，但是新老笔记依然会有抢流量的情况。


#2、注意冷启动AB与标准AB的差异性。
